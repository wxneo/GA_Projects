# %% [markdown]
# # YOLOv5 Model

# %%
# Import google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
HOME = '/content/drive/MyDrive/GA_Capstone/yolov5'

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# !pip install --upgrade ultralytics
# !pip install --upgrade pillow

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20
# !pip install ultralytics==8.0.134

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 064365d8683fd002e9ad789c1e91fa3d021b44f0
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15835, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 15835 (delta 24), reused 34 (delta 11), pack-reused 15768
# Receiving objects: 100% (15835/15835), 14.65 MiB | 23.05 MiB/s, done.
# Resolving deltas: 100% (10836/10836), done.
# /content/yolov5
# HEAD is now at 064365d Update parse_opt() in export.py to work as in train.py (#10789)

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.4 MB/s eta 0:00:00
# Setup complete. Using torch 2.0.1+cu118 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %% [markdown]
# ## Download Dataset from Roboflow API

# %%
#follow the link below to get your download code from from Roboflow
# !pip install -q roboflow
# from roboflow import Roboflow
# rf = Roboflow(model_format="yolov5", notebook="roboflow-yolov5")

# %%
# !pip install roboflow --quiet

# %cd content/yolov5

from roboflow import Roboflow
rf = Roboflow(api_key="sChcgSlVT8i3MuiPPAj8")
project = rf.workspace("ga-capstone-3f9vu").project("crowd_count_v2")
dataset = project.version(3).download("yolov5")
# Out:
# [Errno 2] No such file or directory: 'content/yolov5'
# /content/drive/MyDrive/GA_Capstone/yolov5/runs/train/yolov5s_results6
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Crowd_Count_v2-3 in yolov5pytorch:: 100%|██████████| 7984/7984 [00:57<00:00, 139.54it/s]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5
# %cd {HOME}
# !python train.py --resume {HOME}/runs/train/yolov5s_results/weights/last.pt --img 640 --batch 16 --epochs 100 --data Crowd_Count_v2-3/data.yaml --cfg models/yolov5s.yaml --weights '' --name yolov5s_results  --cache --project '/content/drive/MyDrive/GA_Capstone/yolov5/' --name 'backup'
# !python train.py --img 640 --batch 16 --epochs 100 --data {HOME}/datasets/Crowd_Count_v2-3/data.yaml --cfg models/yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/drive/MyDrive/GA_Capstone/yolov5
# train: weights=, cfg=models/yolov5s.yaml, data=/content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2023-7-28 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# ## Modeling

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd {HOME}

# !python train.py --resume {HOME}/runs/train/yolov5s_results6/weights/last.pt --img 640 --batch 16 --epochs 100 --data {HOME}/datasets/Crowd_Count_v2-3/data.yaml --cfg models/yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/drive/MyDrive/GA_Capstone/yolov5
# train: weights=, cfg=models/yolov5s.yaml, data=/content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=/content/drive/MyDrive/GA_Capstone/yolov5/runs/train/yolov5s_results6/weights/last.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2023-7-28 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd {HOME}

# !python train.py --resume {HOME}/runs/train/yolov5s_results6/weights/last.pt --img 640 --batch 16 --epochs 100 --data {HOME}/datasets/Crowd_Count_v2-3/data.yaml --cfg models/yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/drive/MyDrive/GA_Capstone/yolov5
# train: weights=, cfg=models/yolov5s.yaml, data=/content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=/content/drive/MyDrive/GA_Capstone/yolov5/runs/train/yolov5s_results6/weights/last.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2023-7-28 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# ## Evaluate Model Detector Performance

# %%
# %cd {HOME}
# Validation on train set
# !python val.py  --data {HOME}/datasets/Crowd_Count_v2-3/data.yaml --weights {HOME}/runs/train/yolov5s_results6/weights/best.pt --task train
# Out:
# /content/drive/MyDrive/GA_Capstone/yolov5
# val: data=/content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/data.yaml, weights=['/content/drive/MyDrive/GA_Capstone/yolov5/runs/train/yolov5s_results6/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=train, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 2023-7-28 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 16.5MB/s]
# train: Scanning /content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/train/labels.cache... 2788 images, 0 backgrounds, 0 corrupt: 100% 2788/2788 [00:00<?, ?it/s]
# ...

# %%
# %cd {HOME}
# Validation on val set
# !python val.py  --data {HOME}/datasets/Crowd_Count_v2-3/data.yaml --weights {HOME}/runs/train/yolov5s_results6/weights/best.pt --task val
# Out:
# /content/drive/MyDrive/GA_Capstone/yolov5
# val: data=/content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/data.yaml, weights=['/content/drive/MyDrive/GA_Capstone/yolov5/runs/train/yolov5s_results6/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 2023-7-28 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/valid/labels.cache... 799 images, 0 backgrounds, 0 corrupt: 100% 799/799 [00:00<?, ?it/s]
# ...

# %%
# %cd {HOME}
# Validation on test set
# !python val.py  --data {HOME}/datasets/Crowd_Count_v2-3/data.yaml --weights {HOME}/runs/train/yolov5s_results6/weights/best.pt --task test
# Out:
# /content/drive/MyDrive/GA_Capstone/yolov5
# val: data=/content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/data.yaml, weights=['/content/drive/MyDrive/GA_Capstone/yolov5/runs/train/yolov5s_results6/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 2023-7-28 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/test/labels... 399 images, 0 backgrounds, 0 corrupt: 100% 399/399 [01:51<00:00,  3.59it/s]
# ...

# %% [markdown]
# ## Model Inference

# %%
# use the best weights!
# %cd {HOME}
# !python detect.py --weights {HOME}/runs/train/yolov5s_results6/weights/best.pt --img 640 --conf 0.4 --source {HOME}/datasets/Crowd_Count_v2-3/test/images
# Out:
# /content/drive/MyDrive/GA_Capstone/yolov5
# detect: weights=['/content/drive/MyDrive/GA_Capstone/yolov5/runs/train/yolov5s_results6/weights/best.pt'], source=/content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-7-28 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/399 /content/drive/MyDrive/GA_Capstone/yolov5/datasets/Crowd_Count_v2-3/test/images/img_1003_jpg.rf.c64592f26261c2e2b06016616747b666.jpg: 640x640 52 0s, 11.5ms
# ...

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
